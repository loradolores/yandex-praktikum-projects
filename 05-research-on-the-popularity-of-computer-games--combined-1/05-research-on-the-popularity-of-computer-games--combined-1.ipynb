# %% [markdown]
# # Исследование популярности компьютерных игр
#
# <h2> (Тема №5: Сборный проект - 1) <a class="tocSkip"> </h2>

# %% [markdown]
# <a name="1"></a>
# ## 1. Содержание

# %% [markdown]
# [1. Содержание](#1)
#
# [2. Описание проекта](#2)
#
# *    [2.1. Цель проекта](#21)
# *    [2.2. Задачи проекта](#22)
# *    [2.3. Описание данных](#23)
# *    [2.4. План работы](#24)
#
# [3. Изучение данных](#3)
#
# *    [3.1. Общая информация](#31)
# *    [3.2. Вывод](#32)
#
# [4. Подготовка данных](#4)
#
# *    [4.1. Стиль заголовков](#41)
# *    [4.2. Типы данных и пропуски](#42)
# *    [4.3. Суммарные продажи](#43)
# *    [4.4. Вывод](#44)
#
# [5. Исследовательский анализ данных](#5)
#
# *    [5.1. Выпуск игр в разные годы](#51)
# *    [5.2. Продажи по платформам в разные годы](#52)
# *    [5.3. Продажи по платформам за 2014-2016 гг.](#53)
# *    [5.4. Диаграмма размаха продаж по платформам за 2014-2016 гг.](#54)
# *    [5.5. Проверка гипотез 1 и 2](#55)
#
#     *    [5.5.1. Влияние отзывов на продажи платформы "PS4"](#551)
#     *    [5.5.2. Влияние отзывов на продажи платформы "PS3"](#552)
#     *    [5.5.3. Влияние отзывов на продажи платформы "X360"](#553)
#     *    [5.5.4. Вывод по п. 5.5](#554)
#
# *    [5.6. Продажи по жанрам за 2014-2016 гг.](#56)
# *    [5.7. Вывод](#57)
#
# [6. Портрет пользователя каждого региона](#6)
#
# *    [6.1. Самые популярные платформы (топ-5)](#61)
# *    [6.2. Самые популярные жанры (топ-5)](#62)
# *    [6.3. Проверка гипотезы 3](#63)
# *    [6.4. Вывод](#64)
#
# [7. Проверка гипотез 4 и 5](#7)
#
# *    [7.1. Гипотеза 4](#71)
# *    [7.2. Гипотеза 5](#72)
# *    [7.3. Вывод](#73)
#
# [8. Общий вывод](#8)

# %% [markdown]
# <a name="2"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 2. Описание проекта

# %% [markdown]
# Мы работаем в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, "Xbox" или "PlayStation"). Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и мы планируем кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируем ли мы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура *ESRB (Entertainment Software Rating Board)* — это ассоциация, определяющая возрастной рейтинг компьютерных игр. *ESRB* оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# <a name="21"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 2.1. Цель проекта

# %% [markdown]
# Провести исследование с целью выявить определяющие успешность компьютерных игр закономерности.
#
# Результаты исследования позволят сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# <a name="22"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 2.2. Задачи проекта

# %% [markdown]
# 1. Изучить данные.
# 2. Подготовить данные.
# 3. Выполнить исследовательский анализ данных.
# 4. Составить портрет пользователя каждого региона.
# 5. Проверить гипотезы.
# 6. Написать общий вывод.
#
# В ходе проведения исследования необходимо проверить несколько гипотез:
#
# - Гипотеза 1: отзывы критиков влияют на продажи внутри популярной платформы;
# - Гипотеза 2: отзывы пользователей влияют на продажи внутри популярной платформы;
# - Гипотеза 3: рейтинг *ESRB* влияет на продажи в отдельном регионе;
# - Гипотеза 4: средние пользовательские рейтинги платформ "Xbox One" и "PC" одинаковые;
# - Гипотеза 5: средние пользовательские рейтинги жанров "Action" (англ. «действие», экшен-игры) и "Sports" (англ. «спортивные соревнования») одинаковые.

# %% [markdown]
# <a name="23"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 2.3. Описание данных

# %% [markdown]
# Входные данные: исторические данные интернет-магазина «Стримчик» о продажах компьютерных игр по всему миру, оценки пользователей и экспертов, жанры и платформы (например, "Xbox" или "PlayStation").
#
# Файл: `games.csv`.
#
# Описание столбцов:
#
# - `Name` — название игры
# - `Platform` — платформа
# - `Year_of_Release` — год выпуска
# - `Genre` — жанр игры
# - `NA_sales` — продажи в Северной Америке (миллионы проданных копий)
# - `EU_sales` — продажи в Европе (миллионы проданных копий)
# - `JP_sales` — продажи в Японии (миллионы проданных копий)
# - `Other_sales` — продажи в других странах (миллионы проданных копий)
# - `Critic_Score` — оценка критиков (максимум 100)
# - `User_Score` — оценка пользователей (максимум 10)
# - `Rating` — рейтинг от организации *ESRB* (англ. *Entertainment Software Rating Board*). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# <a name="24"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 2.4. План работы

# %% [markdown]
# **Шаг 1. Изучение данных:**
# - Откроем файл с данными и изучим общую информацию.
#
# **Шаг 2. Подготовка данных:**
# - Заменим названия столбцов (приведём к нижнему регистру);
# - Преобразуем данные в нужные типы. Опишем, в каких столбцах заменили тип данных и почему;
# - Обработаем пропуски при необходимости:
#    - Объясним, почему заполнили пропуски определённым образом или почему не стали это делать;
#    - Опишем причины, которые могли привести к пропускам;
#    - Обратим внимание на аббревиатуру "tbd" в столбце с оценкой пользователей. Отдельно разберём это значение и опишем, как его обработать;
# - Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец.
#
# **Шаг 3. Исследовательский анализ данных:**
# - Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмём данные за соответствующий актуальный период. Актуальный период определим самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - Не нужно учитывать в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберем несколько потенциально прибыльных платформ.
# - Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишем результат.
# - Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируем выводы.
# - Соотнесём выводы с продажами игр на других платформах.
# - Посмотрим на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# **Шаг 4. Составление портрета пользователя каждого региона:**
#
# Определим для пользователя каждого региона (*NA*, *EU*, *JP*):
# - Самые популярные платформы (топ-5). Опишем различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясним разницу.
# - Влияет ли рейтинг *ESRB* на продажи в отдельном регионе?
#
# **Шаг 5. Проверка гипотез:**
# - Средние пользовательские рейтинги платформ "Xbox One" и "PC" одинаковые;
# - Средние пользовательские рейтинги жанров "Action" (англ. «действие», экшен-игры) и "Sports" (англ. «спортивные соревнования») разные.
#
# Зададим самостоятельно пороговое значение *alpha*.
#
# Поясним:
# - Как мы сформулировали нулевую и альтернативную гипотезы;
# - Какой критерий применили для проверки гипотез и почему.
#
# **Шаг 6. Общий вывод:**
#
# - Опишем полученные результаты и зафиксируем основной вывод проведённого исследования.

# %% [markdown]
# <a name="3"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 3. Изучение данных

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats as st

# %% [markdown]
# <a name="31"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 3.1. Общая информация

# %% [markdown]
# Откроем файл `games.csv`, сохраним датафрейм в переменную `games`.

# %%
try:
    games = pd.read_csv('/datasets/games.csv')
except:
    try:
        games = pd.read_csv(r'C:/Users/lorad/OneDrive/Documents/Моя папка/Data Science/Курсы/'
                             'Яндекс.Практикум. Специалист по Data Science/Проектная работа/'
                             '05. Сборный Проект - 1/games.csv')
    except:
        try:
            games = pd.read_csv(r'D:/Юлия/Data Science/Курсы/'
                                 'Яндекс.Практикум. Специалист по Data Science/Проектная работа/'
                                 '05. Сборный Проект - 1/games.csv')
        except:
            games = pd.read_csv('https://docs.google.com/spreadsheets/d/e/'
            '2PACX-1vTYSN-nTVNZZ_ixixCayB23-ExB24cipZ9qS6XRyOFFYBGOigiZIgbMymHYNSxT0vtSLRxveukxCw_x/'
                                'pub?gid=1226056114&single=true&output=csv')

# %% [markdown]
# Выведем первые 5 строк датафрейма `games`.

# %%
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Выведем основную информацию для датафрейма `games` с помощью метода `.info()`.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Исходя из данных `Non-Null Count`, видно, что во многих столбцах присутствуют пропуски.
#
# Выведем числовое описание данных, применив метод `.describe()`.

# %%
display(games.describe())
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Построим общую гистограмму для всех столбцов таблицы.

# %%
games.hist(figsize=(12, 10))
plt.show()

# %% [markdown]
# Проверим явные дубликаты в датафрейме.

# %%
games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <a name="32"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 3.2. Вывод

# %% [markdown]
# В разделе [**Изучение данных**](#3.-Изучение-данных) были выполнены следующие задачи:
# 1. Данные загружены из файла в датафрейм.
# 2. Изучена общая информация о полученном датафрейме.
# 3. Построена общая гистограмма для всех числовых столбцов таблицы.
# 4. Датафрейм проверен на явные дубликаты.
#
# В результате выполнения задач этого раздела было выявлено следующее:
# 1. Явных дубликатов в датафрейме нет.
# 2. Во многих столбцах присутствуют пропуски.
# 3. Типы ряда столбцов не соответствуют их значениям.
# 4. Выпуск игр достигал максимума в районе 2010 года.
# 5. Большинство критиков даёт оценку играм в 70-80 баллов.

# %% [markdown]
# <a name="4"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 4. Подготовка данных

# %% [markdown]
# <a name="41"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 4.1. Стиль заголовков

# %% [markdown]
# Заменим названия столбцов (приведём к нижнему регистру).

# %%
games.columns = games.columns.str.lower()
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <a name="42"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 4.2. Типы данных и пропуски

# %% [markdown]
# Приведём столбцы `year_of_release` и `user_score` к типам `integer` и `float`, соответственно.

# %%
games['year_of_release'].value_counts()
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2007.0    1197
# 2011.0    1136
# 2006.0    1006
# 2005.0     939
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     502
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# Name: year_of_release, dtype: int64

# %%
games['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# В столбце `year_of_release` нет неожиданных данных. А в столбце `user_score` есть строковые данные "tbd" в количестве 2424 при общем количестве данных в этом столбце - 10014.
#
# Посмотрим количество пропусков в столбце `year_of_release`.

# %%
games['year_of_release'].isna().sum()
# Out:
# 269

# %% [markdown]
# В столбце `year_of_release` содержится всего 269 пропусков, при общем количестве строк в датафрейме - 16715. Поэтому эти 269 строк с пропусками можно удалить. Это существенно не повлияет на результаты анализа. Пропуски в этом столбце можно считать случайностью (скорее данные просто не были внесены).
#
# Удалим пропуски в столбце `year_of_release`.

# %%
games = games.dropna(subset=['year_of_release']).reset_index(drop=True)
games['year_of_release'].isna().sum()
# Out:
# 0

# %% [markdown]
# Столбец `year_of_release` имеет тип `float`, хотя в нём хранятся годы выпуска. Поэтому данные этого столбца лучше привести к типу `integer`.
#
# Приведём столбец `year_of_release` к типу `integer`.

# %%
games['year_of_release'] = games['year_of_release'].astype('int')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16446 entries, 0 to 16445
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16446 non-null  object
#  2   year_of_release  16446 non-null  int32
#  3   genre            16444 non-null  object
#  4   na_sales         16446 non-null  float64
#  5   eu_sales         16446 non-null  float64
#  6   jp_sales         16446 non-null  float64
#  7   other_sales      16446 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       9839 non-null   object
#  10  rating           9768 non-null   object
# dtypes: float64(5), int32(1), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# Посмотрим количество пропусков в столбце `user_score`.

# %%
games['user_score'].isna().sum()
# Out:
# 6607

# %% [markdown]
# Также в столбце `user_score` есть строковые данные "tbd" в количестве 2376.

# %%
games['user_score'].value_counts()
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# В столбце `user_score` содержится очень много пропусков - 6607, при общем количестве строк в датафрейме - 16715. Это можно объяснить тем, что пользователи не всегда оставляют оценки продукту, который они покупают. Такое большое количество строк с  пропусками нельзя удалять, иначе мы потеряем огромную часть датафрейма. Из-за содержащихся в нём строковых значений "tbd", столбец имеет тип `object`. Значения "tbd", возможно, появились в результате сбоя. Для дальнейшего анализа и построения графиков необходимо привести данные этого столбца к типу `float`. Для этого необходимо заменить значения "tbd" в столбце `user_score` на значения "NaN" (имеющие тип `float`), т.к. мы не можем вписать конкретные значения рейтинга, чтобы не исказить данные. Удалять строки с "tbd" так же нельзя, т.к. их количество велико - 2376.
#
# Заменим данные "tbd" в столбце `user_score` на "NaN" (значения типа `float`).

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN)

# %% [markdown]
# Проверим столбец `user_score` ещё раз.

# %%
games['user_score'].value_counts()
# Out:
# 7.8    322
# 8      285
# 8.2    276
# 8.3    252
# 7.5    249
#       ...
# 1.5      2
# 0.3      2
# 1.1      2
# 0        1
# 9.7      1
# Name: user_score, Length: 95, dtype: int64

# %% [markdown]
# Приведём столбец `user_score` к типу `float`.

# %%
games['user_score'] = pd.to_numeric(games['user_score'])

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16446 entries, 0 to 16445
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16446 non-null  object
#  2   year_of_release  16446 non-null  int32
#  3   genre            16444 non-null  object
#  4   na_sales         16446 non-null  float64
#  5   eu_sales         16446 non-null  float64
#  6   jp_sales         16446 non-null  float64
#  7   other_sales      16446 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# Посмотрим количество пропусков в столбце `rating`.

# %%
games['rating'].isna().sum()
# Out:
# 6678

# %% [markdown]
# Пропусков в столбце `rating` очень много. Так как этот столбец категориальный, пропуски в нём можно сделать еще одной категорией и заполнить значением "unknown".

# %%
games['rating'] = games['rating'].fillna('unknown')

# %% [markdown]
# Проверим пропуски в столбце `rating` ещё раз.

# %%
games['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# В столбце `rating` есть редкие категории ("EC", "K-A", "RP", "AO"), которые можно заменить на значение "unknown".

# %%
games['rating'].value_counts()
# Out:
# unknown    6678
# E          3921
# T          2905
# M          1536
# E10+       1393
# EC            8
# K-A           3
# AO            1
# RP            1
# Name: rating, dtype: int64

# %%
games['rating'] = games['rating'].replace(['EC', 'K-A', 'RP', 'AO'], 'unknown')

# %% [markdown]
# Проверим данные в столбце `rating` ещё раз.

# %%
games['rating'].value_counts()
# Out:
# unknown    6691
# E          3921
# T          2905
# M          1536
# E10+       1393
# Name: rating, dtype: int64

# %% [markdown]
# <a name="43"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 4.3. Суммарные продажи

# %% [markdown]
# Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец `total_sales` (миллионы проданных копий).

# %%
games['total_sales'] = games.loc[:, 'na_sales':'other_sales'].sum(axis=1)
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %% [markdown]
# <a name="44"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 4.4. Вывод

# %% [markdown]
# В разделе [**Подготовка данных**](#4.-Подготовка-данных) были выполнены следующие задачи:
# 1. Заменены названия столбцов (приведены к нижнему регистру).
# 2. Изменены типы данных в столбцах `year_of_release` и `user_score`.
# 3. Обработаны пропуски.
# 4. Посчитаны суммарные продажи во всех регионах.
#
# В результате выполнения задач этого раздела было выявлено следующее:
# 1. В столбце `user_score` содержится очень много пропусков - 6607, при общем количестве строк в датафрейме - 16715. Это можно объяснить тем, что пользователи не всегда оставляют оценки продукту, который они покупают.
# 2. Значения "tbd" в столбце `user_score`, возможно, появились в результате сбоя. Удалять строки с "tbd" нельзя, т.к. их количество велико - 2376. Поэтому значения "tbd" заменили на значения "NaN" (имеющие тип `float`).
# 3. Пропусков в столбце `rating` очень много, поэтому их вместе с редкими категориями заполнили значением "unknown".

# %% [markdown]
# <a name="5"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 5. Исследовательский анализ данных

# %% [markdown]
# <a name="51"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.1. Выпуск игр в разные годы

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games.groupby('year_of_release')['name'].count()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %% [markdown]
# Исходя из выведенной выше информации, заметно, что количество игр до 1994 года очень мало. Поэтому данные до 1994 года можно считать не представляющими важности.

# %%
games.groupby('year_of_release')['name'].count().\
plot(grid=True, figsize=(16, 5), title='Распределение выпуска игр по годам')
plt.xlabel('Год выпуска игр')
plt.ylabel('Количество выпущенных игр')
plt.show()

# %% [markdown]
# <a name="52"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.2. Продажи по платформам в разные годы

# %% [markdown]
# Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
games.groupby('platform')['total_sales'].sum().sort_values(ascending=False)
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.34
# Wii      891.18
# DS       802.78
# PS       727.58
# PS4      314.14
# GBA      312.88
# PSP      289.53
# 3DS      257.81
# PC       255.76
# GB       254.43
# XB       251.57
# NES      251.05
# N64      218.01
# SNES     200.04
# GC       196.73
# XOne     159.32
# 2600      86.48
# WiiU      82.19
# PSV       53.81
# SAT       33.59
# GEN       30.77
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: total_sales, dtype: float64

# %% [markdown]
# Выберем первые 6 платформ из отсортированных выше данных.

# %%
# с помощью сводной таблицы выберем первые 6 платформ 
# из отсортированных данных выше
total_top_platforms = games.pivot_table(
    index='platform', values='total_sales', aggfunc='sum')\
.sort_values(by='total_sales', ascending=False
).head(6).index

# отфильтруем эти платформы в датафрейме games 
# и построим распределение по годам
games[games['platform'].isin(total_top_platforms)].groupby(
    ['platform', 'year_of_release']
)['total_sales'].sum().unstack('platform').\
plot(grid=True, figsize=(16, 6), 
     title='Распределение платформ с наибольшими суммарными продажами по годам')
plt.xlabel('Год выпуска игр на платформах')
plt.ylabel('Количество платформ (миллионы проданных копий)')
plt.show()

# %% [markdown]
# В качестве среднего жизненного цикла платформы будем считать 2 года. Данные за 2014-2016 гг. помогут построить прогноз на 2017 год. Данные за предыдущие годы учитывать не будем.
#
# Все расчёты ниже будут выполнены на период 2014-2016 гг.

# %% [markdown]
# <a name="53"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.3. Продажи по платформам за 2014-2016 гг.

# %% [markdown]
# Возьмём данные за 2014-2016 гг. Какие платформы лидируют по продажам, растут или падают? Выберем несколько потенциально прибыльных платформ.
#
# Создадим новый датафрейм, содержащий данные с 2014 по 2016 гг.

# %%
actual_games = games[games['year_of_release'] >= 2014].reset_index(drop=True)
actual_games.head()
# Out:
#                                         name platform  year_of_release  \
# 0                  Call of Duty: Black Ops 3      PS4             2015
# 1                         Grand Theft Auto V      PS4             2014
# 2  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 3                                    FIFA 16      PS4             2015
# 4               Star Wars Battlefront (2015)      PS4             2015
#
#           genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0       Shooter      6.03      5.86      0.36         2.38           NaN
# 1        Action      3.96      6.31      0.38         1.97          97.0
# 2  Role-Playing      4.35      3.49      3.10         0.74           NaN
# 3        Sports      1.12      6.12      0.06         1.28          82.0
# 4       Shooter      2.99      3.49      0.22         1.28           NaN
#
#    user_score   rating  total_sales
# 0         NaN  unknown        14.63
# ...

# %%
actual_games.groupby(
    ['platform', 'year_of_release']
)['total_sales'].sum().unstack('platform').\
plot(grid=True, figsize=(16, 6), 
     title='Распределение продаж платформ c 2014 по 2016 гг.')
plt.xlabel('Год выпуска игр на платформах')
plt.ylabel('Количество платформ (миллионы проданных копий)')
x_ticks = [2014, 2015, 2016]
x_labels = [2014, 2015, 2016]
plt.xticks(ticks=x_ticks, labels=x_labels) 
plt.show()

# %% [markdown]
# Чтобы было проще ориентрироваться в цветовой схеме линий диаграммы, выведем данные в виде таблицы.

# %%
actual_games.groupby(
    ['platform', 'year_of_release']
)['total_sales'].sum().unstack('platform')
# Out:
# platform           3DS     PC    PS3     PS4   PSP    PSV   Wii   WiiU   X360  \
# year_of_release
# 2014             43.76  13.28  47.76  100.00  0.24  11.90  3.75  22.03  34.74
# 2015             27.78   8.52  16.82  118.90  0.12   6.25  1.14  16.35  11.96
# 2016             15.14   5.25   3.60   69.25   NaN   4.25  0.18   4.60   1.52
#
# platform          XOne
# year_of_release
# 2014             54.07
# 2015             60.14
# 2016             26.15

# %% [markdown]
# Мы видим, что в период c 2014 по 2016 гг. лидируют по продажам платформы - "PS4" и "XOne", растущих нет и падают - все оставшиеся. Потенциально прибыльные платформы - "PS4" и "XOne".

# %% [markdown]
# <a name="54"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.4. Диаграмма размаха продаж по платформам за 2014-2016 гг.

# %% [markdown]
# Построим диаграмму размаха («ящик с усами») по глобальным продажам игр в период c 2014 по 2016 гг. в разбивке по платформам. Опишем результат.

# %%
actual_games.boxplot(by='platform', column='total_sales', figsize=(16, 7))
plt.title('Диаграмма размаха по глобальным продажам игр '
          'в период c 2014 по 2016 гг. в разбивке по платформам (с выбросами)')
plt.xlabel('Платформы')
plt.ylabel('Количество проданных игр (миллионы проданных копий)')
plt.show()

# %% [markdown]
# Из-за выбросов сложно рассмотреть распределение внутри ящиков, поэтому сделаем второй график без выбросов, указав параметр `showfliers=False`.

# %%
actual_games.boxplot(
    by='platform', column='total_sales', showfliers=False, figsize=(16, 7))
plt.title('Диаграмма размаха по глобальным продажам игр '
          'в период c 2014 по 2016 гг. в разбивке по платформам (без выбросов)')
plt.xlabel('Платформы')
plt.ylabel('Количество проданных игр (миллионы проданных копий)')
plt.show()

# %% [markdown]
# На диаграмме размаха (или «ящик с усами») видно, что в период c 2014 по 2016 гг. имеются сильные верхние выбросы по глобальным продажам игр у платформ "3DS", "PC", "PS3", "PS4", "WiiU", "X360" и "XOne". Особенно сильно выбросы выражены у платформ "3DS", "PS4" и "XOne". Выбросы говорят о наличии очень хороших продаж (т.е. хитовых игр). Об этом же говорят и большие межквартильные размахи у этих платформ. Это означает, что их продажи очень сильно варьируются.
#
# Сравнение медиан глобальных продаж игр по платформам говорит о том, что самыми популярными в период c 2014 по 2016 гг. являются платформы "PS4", "Wii", "WiiU", "X360" и "XOne".

# %% [markdown]
# <a name="55"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# ### 5.5. Проверка гипотез 1 и 2

# %% [markdown]
# Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния за период c 2014 по 2016 гг. и посчитаем корреляцию между отзывами и продажами.

# %% [markdown]
# <a name="551"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# #### 5.5.1. Влияние отзывов на продажи платформы "PS4"

# %% [markdown]
# Рассмотрим популярную платформу "PS4".

# %%
# отзывы критиков
games[(games['platform'] == 'PS4') & (games['year_of_release'] >= 2014)]\
.plot(x='critic_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы критиков о платформе PS4')
plt.xlabel('Оценка критиков (максимум 100)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

critic_ratio = games[(games['platform'] == 'PS4')\
                     & (games['year_of_release'] >= 2014)]['critic_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {critic_ratio:.2f}')


# отзывы пользователей
games[(games['platform'] == 'PS4') & (games['year_of_release'] >= 2014)]\
.plot(x='user_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы пользователей о платформе PS4')
plt.xlabel('Оценка пользователей (максимум 10)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

user_ratio = games[(games['platform'] == 'PS4')\
                   & (games['year_of_release'] >= 2014)]['user_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {user_ratio:.2f}')
# Out:
# Коэффициент корреляции Пирсона: 0.40
# Коэффициент корреляции Пирсона: -0.04

# %% [markdown]
# На верхней диаграмме рассеяния за период c 2014 по 2016 гг. видно, что оценки критиков (`critic_score`) влияют на суммарные продажи платформы "PS4", начиная со значения 60. Засчёт этого, в целом, наблюдается заметная корреляция между отзывами критиков и суммарными продажами (коэффициент корреляции Пирсона = 0,40).
#
# На нижней диаграмме рассеяния за период c 2014 по 2016 гг. не отмечается какой-либо существенной зависимости между оценкой пользователей (`user_score`) и суммарными продажами. Отдельные точки вверху диаграммы скорее похожи на выбросы. Засчёт этого, в целом, корреляция между отзывами пользователей и суммарными продажами практически отсутствует (коэффициент корреляции Пирсона = -0,04).

# %% [markdown]
# <a name="552"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# #### 5.5.2. Влияние отзывов на продажи платформы "PS3"

# %% [markdown]
# Рассмотрим популярную платформу "PS3".

# %%
# отзывы критиков
games[(games['platform'] == 'PS3') & (games['year_of_release'] >= 2014)]\
.plot(x='critic_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы критиков о платформе PS3')
plt.xlabel('Оценка критиков (максимум 100)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

critic_ratio = games[(games['platform'] == 'PS3')\
                     & (games['year_of_release'] >= 2014)]['critic_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {critic_ratio:.2f}')


# отзывы пользователей
games[(games['platform'] == 'PS3') & (games['year_of_release'] >= 2014)]\
.plot(x='user_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы пользователей о платформе PS3')
plt.xlabel('Оценка пользователей (максимум 10)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

user_ratio = games[(games['platform'] == 'PS3')\
                   & (games['year_of_release'] >= 2014)]['user_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {user_ratio:.2f}')
# Out:
# Коэффициент корреляции Пирсона: 0.45
# Коэффициент корреляции Пирсона: -0.17

# %% [markdown]
# На верхней диаграмме рассеяния за период c 2014 по 2016 гг. видно, что оценки критиков (`critic_score`) влияют на суммарные продажи платформы "PS3", начиная со значения 70. Засчёт этого, в целом, наблюдается заметная корреляция между отзывами критиков и суммарными продажами (коэффициент корреляции Пирсона = 0,45).
#
# На нижней диаграмме рассеяния за период c 2014 по 2016 гг. не отмечается какой-либо существенной зависимости между оценкой пользователей (`user_score`) и суммарными продажами. Отдельные точки вверху диаграммы скорее похожи на выбросы. Засчёт этого, в целом, корреляция между отзывами пользователей и суммарными продажами практически отсутствует (коэффициент корреляции Пирсона = -0,17).

# %% [markdown]
# <a name="553"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# #### 5.5.3. Влияние отзывов на продажи платформы "X360"

# %% [markdown]
# Рассмотрим популярную платформу "X360".

# %%
# отзывы критиков
games[(games['platform'] == 'X360') & (games['year_of_release'] >= 2014)]\
.plot(x='critic_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы критиков о платформе X360')
plt.xlabel('Оценка критиков (максимум 100)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

critic_ratio = games[(games['platform'] == 'X360')\
                     & (games['year_of_release'] >= 2014)]['critic_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {critic_ratio:.2f}')


# отзывы пользователей
games[(games['platform'] == 'X360') & (games['year_of_release'] >= 2014)]\
.plot(x='user_score', y='total_sales', figsize=(8, 6), kind='scatter', 
      title='Отзывы пользователей о платформе X360')
plt.xlabel('Оценка пользователей (максимум 10)')
plt.ylabel('Суммарные продажи (миллионы проданных копий)')
plt.show()

user_ratio = games[(games['platform'] == 'X360')\
                   & (games['year_of_release'] >= 2014)]['user_score']\
.corr(games['total_sales'])

print(f'Коэффициент корреляции Пирсона: {user_ratio:.2f}')
# Out:
# Коэффициент корреляции Пирсона: 0.53
# Коэффициент корреляции Пирсона: -0.14

# %% [markdown]
# На верхней диаграмме рассеяния за период c 2014 по 2016 гг. видно, что оценки критиков (`critic_score`) влияют на суммарные продажи платформы "X360", начиная со значения 70. Засчёт этого, в целом, наблюдается заметная корреляция между отзывами критиков и суммарными продажами (коэффициент корреляции Пирсона = 0,53).
#
# На нижней диаграмме рассеяния за период c 2014 по 2016 гг. не отмечается какой-либо существенной зависимости между оценкой пользователей (`user_score`) и суммарными продажами. Отдельные точки вверху диаграммы скорее похожи на выбросы. Засчёт этого, в целом, корреляция между отзывами пользователей и суммарными продажами практически отсутствует (коэффициент корреляции Пирсона = -0,14).
#
# Для трёх самых популярных платформ "PS4", "PS3" и "X360" корреляция между отзывами и продажами за период c 2014 по 2016 гг. имеет схожий вид.

# %% [markdown]
# <a name="554"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# #### 5.5.4. Вывод по п. 5.5

# %% [markdown]
# В подразделе [**Проверка гипотез 1 и 2**](#5.5.-Проверка-гипотез-1-и-2) были проверены гипотезы 1 и 2, а именно:
# 1. Гипотеза 1: отзывы критиков влияют на продажи внутри популярной платформы;
# 2. Гипотеза 2: отзывы пользователей влияют на продажи внутри популярной платформы.
#
#
# В результате выполнения задач этого подраздела было выявлено следующее:
# 1. Для трёх самых популярных платформ "PS4", "PS3" и "X360" корреляция между отзывами и продажами за период c 2014 по 2016 гг. имеет схожий вид.
#
#
# 2. В целом, наблюдается заметная корреляция между **отзывами критиков** и суммарными продажами:
#     - для платформы "PS4" коэффициент корреляции Пирсона = 0,40;
#     - для платформы "PS3" коэффициент корреляции Пирсона = 0,45;
#     - для платформы "X360" коэффициент корреляции Пирсона = 0,53.
#
#
# 3. При этом какой-либо существенной зависимости между оценкой пользователей и суммарными продажами не отмечается. Отдельные точки вверху диаграмм размаха скорее похожи на выбросы. Засчёт этого, в целом, корреляция между **отзывами пользователей** и суммарными продажами практически отсутствует:
#     - для платформы "PS4" коэффициент корреляции Пирсона = -0,04;
#     - для платформы "PS3" коэффициент корреляции Пирсона = -0,17;
#     - для платформы "X360" коэффициент корреляции Пирсона = -0,14.

# %% [markdown]
# <a name="56"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.6. Продажи по жанрам за 2014-2016 гг.

# %% [markdown]
# Посмотрим на общее распределение игр по жанрам за период c 2014 по 2016 гг. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Выведем суммы, средние значения и медианы продаж по жанрам за период c 2014 по 2016 гг. в порядке убывания их медиан.

# %%
actual_games.groupby('genre')\
.agg({'total_sales':['sum', 'mean', 'median']}).\
sort_values(by=('total_sales', 'median'), ascending=False)
# Out:
#              total_sales
#                      sum      mean median
# genre
# Shooter           170.94  1.335469  0.515
# Sports            109.48  0.680000  0.180
# Platform           18.09  0.476053  0.140
# Fighting           28.22  0.470333  0.125
# Role-Playing      101.44  0.459005  0.110
# Simulation         13.13  0.298409  0.100
# Action            199.36  0.322068  0.090
# Misc               37.55  0.332301  0.090
# Racing             27.52  0.398841  0.090
# Strategy            3.96  0.107027  0.060
# Puzzle              2.21  0.157857  0.045
# Adventure          17.55  0.094865  0.030

# %% [markdown]
# Для того, чтобы определить жанры за период c 2014 по 2016 гг., в которых игры стабильно приносят высокий доход, мы, помимо суммарных продаж, вывели средние и медианные продажи.
#
# Если ориентироваться на медианы, то самыми прибыльными являются жанры "Shooter", "Sports" и "Platform". Средние значения полностью подтверждают это. Жанры с самыми низкими продажами - "Strategy", "Puzzle" и "Adventure".

# %% [markdown]
# <a name="57"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 5.7. Вывод

# %% [markdown]
# В разделе [**Исследовательский анализ данных**](#5.-Исследовательский-анализ-данных) были выполнены следующие задачи:
# 1. Построено распределение выпуска игр по годам.
# 2. Построено распределение платформ с наибольшими суммарными продажами по годам.
# 3. Построено распределение продаж платформ c 2014 по 2016 гг.
# 4. Построена диаграмма размаха продаж по платформам за 2014-2016 гг.
# 5. Проверены гипотезы 1 и 2.
# 6. Построено распределение продаж по жанрам за 2014-2016 гг.
#
#
# В результате выполнения задач этого раздела было выявлено следующее:
# 1. Количество игр до 1994 года очень мало. Поэтому данные до 1994 года можно считать не представляющими важности.
# 2. В качестве среднего жизненного цикла платформы будем считать 2 года. Данные за 2014-2016 гг. помогут построить прогноз на 2017 год. Данные за предыдущие годы учитывать не будем.
# 3. В период c 2014 по 2016 гг. лидируют по продажам платформы - "PS4" и "XOne", растущих нет и падают - все оставшиеся. Потенциально прибыльные платформы - "PS4" и "XOne".
# 4. На диаграмме размаха видно, что в период c 2014 по 2016 гг. имеются сильные верхние выбросы по глобальным продажам игр у платформ "3DS", "PC", "PS3", "PS4", "WiiU", "X360" и "XOne". Особенно сильно выбросы выражены у платформ "3DS", "PS4" и "XOne". Выбросы говорят о наличии очень хороших продаж (т.е. хитовых игр). Об этом же говорят и большие межквартильные размахи у этих платформ. Это означает, что их продажи очень сильно варьируются.
# 5. Сравнение медиан глобальных продаж игр по платформам говорит о том, что самыми популярными в период c 2014 по 2016 гг. являются платформы "PS4", "Wii", "WiiU", "X360" и "XOne".
# 6. Для трёх самых популярных платформ "PS4", "PS3" и "X360" корреляция между отзывами и продажами за период c 2014 по 2016 гг. имеет схожий вид.
#
#  В целом, наблюдается заметная корреляция между **отзывами критиков** и суммарными продажами:
#     - для платформы "PS4" коэффициент корреляции Пирсона = 0,40;
#     - для платформы "PS3" коэффициент корреляции Пирсона = 0,45;
#     - для платформы "X360" коэффициент корреляции Пирсона = 0,53.
#
#  При этом какой-либо существенной зависимости между оценкой пользователей и суммарными продажами не отмечается. Отдельные точки вверху диаграмм размаха скорее похожи на выбросы. Засчёт этого, в целом, корреляция между **отзывами пользователей** и суммарными продажами практически отсутствует:
#     - для платформы "PS4" коэффициент корреляции Пирсона = -0,04;
#     - для платформы "PS3" коэффициент корреляции Пирсона = -0,17;
#     - для платформы "X360" коэффициент корреляции Пирсона = -0,14.
#
#
# 7. Если ориентироваться на медианные продажи, то самыми прибыльными за период c 2014 по 2016 гг. являются жанры "Shooter", "Sports" и "Platform". Средние значения полностью подтверждают это. Жанры с самыми низкими продажами - "Strategy", "Puzzle" и "Adventure".

# %% [markdown]
# <a name="6"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 6. Портрет пользователя каждого региона

# %% [markdown]
# <a name="61"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 6.1. Самые популярные платформы (топ-5)

# %% [markdown]
# Определим для пользователя каждого региона (*NA*, *EU*, *JP*) самые популярные платформы (топ-5) за период c 2014 по 2016 гг. Опишем различия в долях продаж.
#
# Выведем продажи платформ для каждого региона (*NA*, *EU*, *JP*) за период c 2014 по 2016 гг. в порядке убывания их популярности для региона *NA* (Северная Америка).

# %%
actual_games.groupby('platform')\
.agg({'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum'}).\
sort_values(by='na_sales', ascending=False)
# Out:
#           na_sales  eu_sales  jp_sales
# platform
# PS4          98.61    130.04     15.02
# XOne         81.27     46.25      0.32
# X360         28.30     15.49      0.08
# 3DS          22.64     16.12     44.24
# PS3          22.05     25.54     11.22
# WiiU         19.36     13.15      7.31
# PC            7.23     17.97      0.00
# PSV           2.52      3.53     14.54
# Wii           2.08      2.59      0.00
# PSP           0.00      0.00      0.36

# %% [markdown]
# Создадим словарь, в котором ключами являются названия столбцов датафрейма `games`, а значениями - названия соответствующих регионов.

# %%
titles = {'na_sales':'NA (Северная Америка)',
          'eu_sales':'EU (Европа)', 'jp_sales':'JP (Япония)'}

# %% [markdown]
# С помощью цикла построим круговые диаграммы с долями продаж самых популярных платформ (топ-5) за период c 2014 по 2016 гг. для регионов *NA* (Северная Америка), *EU* (Европа) и *JP* (Япония).

# %%
for column in ['na_sales', 'eu_sales', 'jp_sales']:
    
    # с помощью сводной таблицы выберем первые 5 самых популярных платформ
    # за период c 2014 по 2016 гг.
    top_platforms = actual_games.pivot_table(
    index='platform', values=column, aggfunc='sum')\
    .sort_values(by=column, ascending=False
    ).head(5)
    
    # создадим новый столбец, в котором все платформы, которые не входят в топ-5,
    # объединены в категорию "Другие"
    actual_games['filter_platform'] = actual_games['platform']\
    .where(actual_games['platform'].isin(top_platforms.index), 'Другие')
    
    # построим круговую диаграмму с долями продаж самых популярных платформ (топ-5)
    # и категории "Другие" за период c 2014 по 2016 гг.
    actual_games.pivot_table(index='filter_platform', values=column, aggfunc='sum').\
    plot(kind='pie', y=column, legend=False, figsize=(10, 10), autopct='%1.0f%%',\
    title=f'Топ-5 самых популярных платформ для региона {titles.get(column)} '
         'за период c 2014 по 2016 гг.')

# %% [markdown]
# Наблюдаются сильные различия в долях продаж топ-5 самых популярных платформ за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой.
#
# Платформа "PS4" занимает значительную долю продаж в Северной Америке (35%) и Европе (48%), в отличие от Японии (только 16%).
#
# Платформа "XOne" также занимает заметную долю продаж в Северной Америке (29%) и Европе (17%), а в Японии она не входит в топ-5.
#
# С другой стороны, в Японии лидирует платформа "3DS" (48%), которая в Северной Америке (8%) и Европе (6%) представлена незначительно.
#
# Примечательно, что категория "Другие" занимает в Японии всего 1%, что говорит о том, что в Северной Америке и Европе ассортимент продаваемых платформ более разнообразен.

# %% [markdown]
# <a name="62"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 6.2. Самые популярные жанры (топ-5)

# %% [markdown]
# Определим для пользователя каждого региона (*NA*, *EU*, *JP*) самые популярные жанры (топ-5) за период c 2014 по 2016 гг. Поясним разницу.
#
# Выведем продажи по жанрам для каждого региона (*NA*, *EU*, *JP*) за период c 2014 по 2016 гг. в порядке убывания их популярности для региона *NA* (Северная Америка).

# %%
actual_games.groupby('genre')\
.agg({'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum'}).\
sort_values(by='na_sales', ascending=False)
# Out:
#               na_sales  eu_sales  jp_sales
# genre
# Shooter          79.02     65.52      4.87
# Action           72.53     74.68     29.58
# Sports           46.13     45.73      3.26
# Role-Playing     33.47     28.17     31.16
# Misc             15.05     12.86      5.61
# Fighting         12.43      6.69      6.37
# Racing            8.74     14.13      1.76
# Platform          6.79      6.80      2.69
# Adventure         5.64      6.49      3.60
# Simulation        2.63      7.30      2.31
# Strategy          0.98      1.79      0.95
# Puzzle            0.65      0.52      0.93

# %% [markdown]
# С помощью цикла построим круговые диаграммы с долями продаж по самым популярным жанрам (топ-5) за период c 2014 по 2016 гг. для регионов *NA* (Северная Америка), *EU* (Европа) и *JP* (Япония).

# %%
for column in ['na_sales', 'eu_sales', 'jp_sales']:
    
    # с помощью сводной таблицы выберем первые 5 самых популярных жанров
    # за период c 2014 по 2016 гг.
    top_genre = actual_games.pivot_table(
    index='genre', values=column, aggfunc='sum')\
    .sort_values(by=column, ascending=False
    ).head(5)
    
    # создадим новый столбец, в котором все жанры, которые не входят в топ-5,
    # объединены в категорию "Другие"
    actual_games['filter_genre'] = actual_games['genre']\
    .where(actual_games['genre'].isin(top_genre.index), 'Другие')
    
    # построим круговую диаграмму с долями продаж по самым популярным жанрам (топ-5)
    # и категории "Другие" за период c 2014 по 2016 гг.
    actual_games.pivot_table(index='filter_genre', values=column, aggfunc='sum').\
    plot(kind='pie', y=column, legend=False, figsize=(10, 10), autopct='%1.0f%%',\
    title=f'Топ-5 самых популярных жанров для региона {titles.get(column)} '
         'за период c 2014 по 2016 гг.')

# %% [markdown]
# Наблюдаются сильные различия в долях продаж топ-5 самых популярных жанров за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой.
#
# Жанры "Shooter" и "Action" занимают значительную долю продаж в Северной Америке (28% и 26%, соответственно) и Европе (24% и 28%, соответственно). В Японии лидируют "Role-Playing" и "Action" (33% и 32%, соответственно). При этом жанр "Role-Playing" в Северной Америке и Европе представлен не так значительно (12% и 10%, соответственно).
#
# Жанр "Sports" также занимает заметную долю продаж в Северной Америке (16%) и Европе (17%), а в Японии он не входит в топ-5.
#
# Категория "Другие" во всех трёх регионах представлена практически одинаково (13%, 16% и 17%, соответственно), что говорит о том, что жанры представлены одинаково разнообразно.

# %% [markdown]
# <a name="63"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# ### 6.3. Проверка гипотезы 3

# %% [markdown]
# Влияет ли рейтинг *ESRB* на продажи в отдельном регионе за период c 2014 по 2016 гг.?
#
# Выведем продажи по рейтингу *ESRB* для каждого региона (*NA*, *EU*, *JP*) за период c 2014 по 2016 гг. в порядке их убывания для региона *NA* (Северная Америка).

# %%
actual_games.groupby('rating')\
.agg({'na_sales': 'sum', 'eu_sales': 'sum', 'jp_sales': 'sum'}).\
sort_values(by='na_sales', ascending=False)
# Out:
#          na_sales  eu_sales  jp_sales
# rating
# M           96.42     93.44      8.01
# unknown     64.72     58.95     56.90
# E           50.74     58.06      8.94
# T           38.95     34.07     14.78
# E10+        33.23     26.16      4.46

# %% [markdown]
# С помощью цикла построим круговые диаграммы с долями продаж, соответствующими рейтингу *ESRB*, за период c 2014 по 2016 гг. для регионов *NA* (Северная Америка), *EU* (Европа) и *JP* (Япония).

# %%
for column in ['na_sales', 'eu_sales', 'jp_sales']:
    
    actual_games.pivot_table(index='rating', values=column, aggfunc='sum').\
    plot(kind='pie', y=column, legend=False, figsize=(10, 10), autopct='%1.0f%%',\
    title=f'Влияние рейтинга ESRB на продажи в регионе {titles.get(column)} '
         'за период c 2014 по 2016 гг.')

# %% [markdown]
# Наблюдаются сильные различия в долях влияния рейтинга *ESRB* на продажи за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой.
#
# Рейтинг *M* влияет на значительную долю продаж в Северной Америке (34%) и Европе (35%). В Японии рейтинг *ESRB* для большей части продаж (61%) неизвестен, что не даёт возможности сделать анализ влияния рейтинга на продажи в этом регионе. Необходимы дополнительные данные.

# %% [markdown]
# <a name="64"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 6.4. Вывод

# %% [markdown]
# В разделе [**Портрет пользователя каждого региона**](#6.-Портрет-пользователя-каждого-региона) были выполнены следующие задачи:
# 1. Определены самые популярные платформы (топ-5) за период c 2014 по 2016 гг.
# 2. Определены самые популярные жанры (топ-5) за период c 2014 по 2016 гг.
# 3. Проверена гипотеза 3: рейтинг *ESRB* влияет на продажи в отдельном регионе.
#
#
# В результате выполнения задач этого раздела было выявлено следующее:
# 1. Наблюдаются сильные различия в долях продаж топ-5 самых популярных **платформ** за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой:
#     - Платформа "PS4" занимает значительную долю продаж в Северной Америке (35%) и Европе (48%), в отличие от Японии (только 16%).
#     - Платформа "XOne" также занимает заметную долю продаж в Северной Америке (29%) и Европе (17%), а в Японии она не входит в топ-5.
#     - С другой стороны, в Японии лидирует платформа "3DS" (48%), которая в Северной Америке (8%) и Европе (6%) представлена незначительно.
#
#  Примечательно, что категория "Другие" занимает в Японии всего 1%, что говорит о том, что в Северной Америке и Европе ассортимент продаваемых платформ более разнообразен.
#
#
# 2. Наблюдаются сильные различия в долях продаж топ-5 самых популярных **жанров** за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой:
#     - Жанры "Shooter" и "Action" занимают значительную долю продаж в Северной Америке (28% и 26%, соответственно) и Европе (24% и 28%, соответственно). В Японии лидируют "Role-Playing" и "Action" (33% и 32%, соответственно). При этом жанр "Role-Playing" в Северной Америке и Европе представлен не так значительно (12% и 10%, соответственно).
#     - Жанр "Sports" также занимает заметную долю продаж в Северной Америке (16%) и Европе (17%), а в Японии он не входит в топ-5.
#
#  Категория "Другие" во всех трёх регионах представлена практически одинаково (13%, 16% и 17%, соответственно), что говорит о том, что жанры представлены одинаково разнообразно.
#
#
# 3. Наблюдаются сильные различия в долях влияния **рейтинга *ESRB*** на продажи за период c 2014 по 2016 гг. между пользователями Северной Америки (*NA*) и Европы (*EU*), с одной стороны, и Японии (*JP*) - с другой:
#     - Рейтинг *M* влияет на значительную долю продаж в Северной Америке (34%) и Европе (35%).
#     - В Японии рейтинг *ESRB* для большей части продаж (61%) неизвестен, что не даёт возможности сделать анализ влияния рейтинга на продажи в этом регионе. Необходимы дополнительные данные.

# %% [markdown]
# <a name="7"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 7. Проверка гипотез 4 и 5

# %% [markdown]
# <a name="71"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# ### 7.1. Гипотеза 4

# %% [markdown]
# Средние пользовательские рейтинги платформ "Xbox One" и "PC" за период c 2014 по 2016 гг. одинаковые.
#
# ```
# H_0: Средний пользовательский рейтинг (`user_score`) платформы "Xbox One" = средний пользовательский рейтинг (`user_score`) платформы "PC".
# H_a: Средний пользовательский рейтинг (`user_score`) платформы "Xbox One" ≠ средний пользовательский рейтинг (`user_score`) платформы "PC".
# alpha = 0.05
# ```

# %% [markdown]
# Удалим пропуски в столбце `user_score`.

# %%
games_user_score = actual_games.dropna(subset=['user_score'])\
.reset_index(drop=True)

games_user_score['user_score'].isna().sum()
# Out:
# 0

# %% [markdown]
# Проверим уникальные значения в столбце `platform` (платформа "Xbox One" внесена под названием "XOne").

# %%
games_user_score['platform'].unique()
# Out:
# array(['PS4', 'WiiU', 'XOne', 'PS3', 'X360', '3DS', 'PC', 'Wii', 'PSV'],
#       dtype=object)

# %%
# results = вызов метода для проверки гипотезы
results = st.ttest_ind(
    games_user_score[games_user_score['platform'] == 'XOne']['user_score'], 
    games_user_score[games_user_score['platform'] == 'PC']['user_score'],
    equal_var = False)

# alpha = задайте значение уровня значимости
alpha = .05

# вывод значения p-value на экран 
print('p-значение:', results.pvalue)

# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.11601398086668832
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <a name="72"></a> <div style="text-align: right"> [Содержание](#1.-Содержание) </div>
# ### 7.2. Гипотеза 5

# %% [markdown]
# Средние пользовательские рейтинги жанров "Action" (англ. «действие», экшен-игры) и "Sports" (англ. «спортивные соревнования») за период c 2014 по 2016 гг. одинаковые.
#
# ```
# H_0: Средний пользовательский рейтинг (`user_score`) жанра "Action" = средний пользовательский рейтинг (`user_score`) жанра "Sports".
# H_a: Средний пользовательский рейтинг (`user_score`) жанра "Action" ≠ средний пользовательский рейтинг (`user_score`) жанра "Sports".
# alpha = 0.05
# ```

# %% [markdown]
# Проверим уникальные значения в столбце `genre` (все значения совпадают с названиями в гипотезах).

# %%
games_user_score['genre'].unique()
# Out:
# array(['Action', 'Sports', 'Shooter', 'Role-Playing', 'Racing',
#        'Platform', 'Simulation', 'Fighting', 'Misc', 'Adventure',
#        'Puzzle', 'Strategy'], dtype=object)

# %%
# results = вызов метода для проверки гипотезы
results = st.ttest_ind(
    games_user_score[games_user_score['genre'] == 'Action']['user_score'], 
    games_user_score[games_user_score['genre'] == 'Sports']['user_score'],
    equal_var = False)

# alpha = задайте значение уровня значимости
alpha = .05

# вывод значения p-value на экран 
print('p-значение:', results.pvalue)

# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.1825550382644557e-14
# Отвергаем нулевую гипотезу

# %% [markdown]
# Для *p*-значений обеих нулевых гипотез не имеет значение, какой критический уровень статистической значимости для их проверки мы выберем (пороговое значение *alpha* = 0,01 или 0,05). *P*-значение для первой нулевой гипотезы = **0,12**, а для второй = $1,18*10^{-14}$. Первая нулевая гипотеза в любом случае не будет отвергнута, а вторая - будет.

# %% [markdown]
# <a name="73"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ### 7.3. Вывод

# %% [markdown]
# В разделе [**Проверка гипотез 4 и 5**](#7.-Проверка-гипотез-4-и-5) были выполнены следующие задачи:
# 1. Проверена гипотеза 4: средние пользовательские рейтинги платформ "Xbox One" и "PC" одинаковые.
# 2. Проверена гипотеза 5: средние пользовательские рейтинги жанров "Action" (англ. «действие», экшен-игры) и "Sports" (англ. «спортивные соревнования») одинаковые.
#
#
# В результате выполнения задач этого раздела было выявлено следующее:
# - Для *p*-значений обеих нулевых гипотез не имеет значение, какой критический уровень статистической значимости для их проверки мы выберем (пороговое значение *alpha* = 0,01 или 0,05). *P*-значение для первой нулевой гипотезы = **0,12**, а для второй = $1,18*10^{-14}$. Первая нулевая гипотеза в любом случае не будет отвергнута, а вторая - будет.

# %% [markdown]
# <a name="8"></a> <div style="text-align: right">[Cодержание](#1.-Содержание)</div>
# ## 8. Общий вывод

# %% [markdown]
# Проведено исследование с целью выявить определяющие успешность компьютерных игр закономерности.
#
# Результаты исследования позволят сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Входные данные: исторические данные интернет-магазина «Стримчик» о продажах компьютерных игр по всему миру, оценки пользователей и экспертов, жанры и платформы (например, "Xbox" или "PlayStation").
#
# Перед проведением исследования были сформулированы несколько гипотез:
#
# - Гипотеза 1: отзывы критиков влияют на продажи внутри популярной платформы;
# - Гипотеза 2: отзывы пользователей влияют на продажи внутри популярной платформы;
# - Гипотеза 3: рейтинг *ESRB* влияет на продажи в отдельном регионе;
# - Гипотеза 4: средние пользовательские рейтинги платформ "Xbox One" и "PC" одинаковые;
# - Гипотеза 5: средние пользовательские рейтинги жанров "Action" (англ. «действие», экшен-игры) и "Sports" (англ. «спортивные соревнования») одинаковые.
#
# В результате удалось выявить следующие зависимости.
#
# <b>Гипотеза 1 подтвердилась:</b>
#
# - 0,40 (для "PS4"), 0,45 (для "PS3"), 0,53 (для "X360") - коэффициенты корреляции Пирсона для зависимости между отзывами критиков и продажами внутри популярных платформ "PS4", "PS3" и "X360", что говорит об увеличении суммарных продаж с ростом оценки критиков.
#
# Рекомендация: несмотря на то, что зависимость линейная, она не прямая, что свидетельствует о влиянии других параметров на увеличение суммарных продаж, подлежащих анализу.
#
# <b>Гипотеза 2 не подтвердилась:</b>
#
# - -0,04 (для "PS4"), -0,17 (для "PS3"), -0,14 (для "X360") - коэффициенты корреляции Пирсона для зависимости между отзывами пользователей и продажами внутри популярных платформ "PS4", "PS3" и "X360", что говорит об отсутствии увеличения суммарных продаж с ростом оценки критиков.
#
# Рекомендация: несмотря на то, что, на первый взгляд, зависимость практически отсутствует, логично предположить, что она имеет более сложный характер. Для её более детального изучения необходим анализ дополнительных данных, не вошедших в настоящее исследование.
#
# <b>Гипотеза 3 подтвердилась частично:</b>
#
# - рейтинг *M* влияет на значительную долю продаж в Северной Америке (34%) и Европе (35%). В Японии рейтинг *ESRB* для большей части продаж (61%) неизвестен, что не даёт возможности сделать анализ влияния рейтинга на продажи в этом регионе.
#
# Рекомендация: для анализ влияния рейтинга *ESRB* на продажи в Японии необходимы дополнительные данные, не вошедшие в настоящее исследование.
#
# <b>Гипотеза 4 подтвердилась:</b>
#
# - **0,12** - *p*-значение для проверенной нулевой гипотезы, и это говорит о том, что нулевая гипотеза не будет отвергнута при любом разумном значении критического уровня статистической значимости (пороговое значение *alpha* = 0,01 или 0,05), т.е. средние пользовательские рейтинги платформ "Xbox One" и "PC" одинаковые.
#
# Рекомендация: для более детального сравнения между собой платформ "Xbox One" и "PC" можно проанализировать дополнительные параметры, не вошедшие в настоящее исследование.
#
# <b>Гипотеза 5 не подтвердилась:</b>
#
# - $1,18*10^{-14}$ - *p*-значение для проверенной нулевой гипотезы, и это говорит о том, что нулевая гипотеза будет отвергнута при любом разумном значении критического уровня статистической значимости (пороговое значение *alpha* = 0,01 или 0,05), т.е. средние пользовательские рейтинги жанров "Action" и "Sports" не одинаковые.
#
# Рекомендация: для более детального сравнения между собой жанров "Action" и "Sports" можно проанализировать дополнительные параметры, не вошедшие в настоящее исследование.
#
# <b>Общие рекомендации:</b>
#
# 1.	Специалистам, которые занимаются исследованием популярности продукта и планированием рекламных кампаний, можно использовать зависимости из гипотез 1 и 4.
# 2.	Необходимо собрать более полную выборку с дополнпительными параметрами (возможно качественными) для повторной проверки гипотез 2, 3 и 5.
